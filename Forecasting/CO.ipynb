# %%
#Import necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_absolute_error
import shap
from sklearn.model_selection import GridSearchCV

# %%
import pickle5 as pickle
import os

# %%
#Creating Fucntion for adding new features seq hour, day, month, weekday, year, weekend, day/night
def Create_Features(data):
  data['seg_hour']=data['DatetimeEnd'].dt.hour
  data['day']=data['DatetimeEnd'].dt.day
  data['month']=data['DatetimeEnd'].dt.month
  data['weekday']=data['DatetimeEnd'].dt.weekday
  data['year']=data['DatetimeEnd'].dt.year
  data['weekend']=[1 if data['weekday'][i] in [5,6] else 0 for i in range(len(data))]
  data['day/night']=[1 if data['seg_hour'][i]<18 and data['seg_hour'][i]>6 else 0 
                     for i in range(len(data))] 
  # day equals 1 and night equals 0
  return data

# %%
#Removing outliers Function

def detect_outliers(data):
    outliers=[]
    threshold=3
    mean = np.mean(data)
    std =np.std(data)
    
    
    for i in data:
        z_score= (i - mean)/std 
        if np.abs(z_score) > threshold:
            outliers.append(i)
    return outliers

# %%
# Datasets input

data1=pd.read_csv("/Users/mariatsiompra/Documents/master/diplwmatiki/Forecasting/data/GR_1_22830_2023_timeseries.csv")
data5=pd.read_csv("/Users/mariatsiompra/Documents/master/diplwmatiki/Forecasting/data/GR_5_64780_2023_timeseries.csv")
data7=pd.read_csv("/Users/mariatsiompra/Documents/master/diplwmatiki/Forecasting/data/GR_7_22824_2023_timeseries.csv")
data8=pd.read_csv("/Users/mariatsiompra/Documents/master/diplwmatiki/Forecasting/data/GR_8_22883_2023_timeseries.csv")
data10=pd.read_csv("/Users/mariatsiompra/Documents/master/diplwmatiki/Forecasting/data/GR_10_22962_2023_timeseries.csv")
data6001=pd.read_csv("/Users/mariatsiompra/Documents/master/diplwmatiki/Forecasting/data/GR_6001_64781_2023_timeseries.csv")

# %%
#Merging all datasets

data=pd.concat([data1,data5,data7,data8,data10,data6001])
data.shape
# Out:
# (18762, 17)

# %%
data['AirPollutant'].unique()
# Out:
# array(['SO2', 'PM10', 'O3', 'NO2', 'CO', 'PM2.5'], dtype=object)

# %%
data.columns
# Out:
# Index(['Countrycode', 'Namespace', 'AirQualityNetwork', 'AirQualityStation',
#        'AirQualityStationEoICode', 'SamplingPoint', 'SamplingProcess',
#        'Sample', 'AirPollutant', 'AirPollutantCode', 'AveragingTime',
#        'Concentration', 'UnitOfMeasurement', 'DatetimeBegin', 'DatetimeEnd',
#        'Validity', 'Verification'],
#       dtype='object')

# %%
#Dropping unnecessary columns and setting datetime column as index
data=data.drop(['SamplingPoint','SamplingProcess','Sample','AveragingTime','UnitOfMeasurement','DatetimeBegin','Verification','Namespace','Countrycode','AirQualityNetwork', 'AirQualityStation',
       'AirQualityStationEoICode','AirPollutantCode','Validity'],axis=1)
data['DatetimeEnd']=pd.to_datetime(data['DatetimeEnd'],utc=True)

# %%
data.head()
# Out:
#   AirPollutant  Concentration               DatetimeEnd
# 0          SO2           10.0 2023-01-01 00:00:00+00:00
# 1          SO2           10.0 2023-01-01 01:00:00+00:00
# 2          SO2           10.0 2023-01-01 02:00:00+00:00
# 3          SO2            9.0 2023-01-01 03:00:00+00:00
# 4          SO2           10.0 2023-01-01 04:00:00+00:00

# %%
#Creting different dataframes for its Pollutant to run the model
data=data[data["AirPollutant"]=="CO"]
# data_NO2=data[data["AirPollutant"]=="NO2"]
# data=data[data["AirPollutant"]=="O3"]
# data=data[data["AirPollutant"]=="PM10"]
# data=data[data["AirPollutant"]=="PM2.5"]
# data=data[data["AirPollutant"]=="SO2"]
data.head()
# Out:
#   AirPollutant  Concentration               DatetimeEnd
# 0           CO            1.9 2023-01-01 00:00:00+00:00
# 1           CO            1.8 2023-01-01 01:00:00+00:00
# 2           CO            1.9 2023-01-01 02:00:00+00:00
# 3           CO            1.5 2023-01-01 03:00:00+00:00
# 4           CO            1.5 2023-01-01 04:00:00+00:00

# %%
#Checking null values
data.dropna(axis=0,inplace=True)
data.isnull().sum()
# Out:
# AirPollutant     0
# Concentration    0
# DatetimeEnd      0
# dtype: int64

# %%
data.reset_index(inplace=True)
data.tail()
# Out:
#       index AirPollutant  Concentration               DatetimeEnd
# 3079   3088           CO            0.7 2023-05-09 17:00:00+00:00
# 3080   3089           CO            0.6 2023-05-09 18:00:00+00:00
# 3081   3090           CO            0.7 2023-05-09 19:00:00+00:00
# 3082   3091           CO            0.7 2023-05-09 20:00:00+00:00
# 3083   3092           CO            0.5 2023-05-09 21:00:00+00:00

# %%
min(data.Concentration)
# Out:
# 0.2

# %%
max(data.Concentration)
# Out:
# 5.3

# %%
Create_Features(data)
# Out:
#       index AirPollutant  Concentration               DatetimeEnd  seg_hour  \
# 0         0           CO            1.9 2023-01-01 00:00:00+00:00         0
# 1         1           CO            1.8 2023-01-01 01:00:00+00:00         1
# 2         2           CO            1.9 2023-01-01 02:00:00+00:00         2
# 3         3           CO            1.5 2023-01-01 03:00:00+00:00         3
# 4         4           CO            1.5 2023-01-01 04:00:00+00:00         4
# ...     ...          ...            ...                       ...       ...
# 3079   3088           CO            0.7 2023-05-09 17:00:00+00:00        17
# 3080   3089           CO            0.6 2023-05-09 18:00:00+00:00        18
# 3081   3090           CO            0.7 2023-05-09 19:00:00+00:00        19
# 3082   3091           CO            0.7 2023-05-09 20:00:00+00:00        20
# 3083   3092           CO            0.5 2023-05-09 21:00:00+00:00        21
#
#       day  month  weekday  year  weekend  day/night
# 0       1      1        6  2023        1          0
# 1       1      1        6  2023        1          0
# 2       1      1        6  2023        1          0
# 3       1      1        6  2023        1          0
# 4       1      1        6  2023        1          0
# ...   ...    ...      ...   ...      ...        ...
# 3079    9      5        1  2023        0          1
# 3080    9      5        1  2023        0          0
# 3081    9      5        1  2023        0          0
# 3082    9      5        1  2023        0          0
# 3083    9      5        1  2023        0          0
#
# [3084 rows x 11 columns]

# %%
#plotting data concentration per hour lineplot
fig=plt.figure(figsize=(15,5))
sns.lineplot(data=data,x='DatetimeEnd',y='Concentration')
plt.title('Concentration per hour',fontsize=15)
plt.xlabel('date',fontsize=15)
plt.ylabel('Concentration',fontsize=15)
plt.show()

# %%
#Concentration per hour boxplot
fig, ax= plt.subplots(figsize= (10,8))
bp = sns.boxplot(data=data,x='seg_hour',y='Concentration')
ax.set_title("Concentration per hour")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a box plot using Seaborn
sns.boxplot(data=data, x='seg_hour',y='Concentration')

# Calculate the relevant statistics
median = data['Concentration'].median()
q1 = data['Concentration'].quantile(0.25)
q3 = data['Concentration'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)

# Add annotations to the plot
plt.text(0.05, 0.9, f'Median: {median:.2f}', transform=plt.gca().transAxes)
plt.text(0.05, 0.85, f'Q1: {q1:.2f}', transform=plt.gca().transAxes)
plt.text(0.05, 0.8, f'Q3: {q3:.2f}', transform=plt.gca().transAxes)
plt.text(0.05, 0.75, f'IQR: {iqr:.2f}', transform=plt.gca().transAxes)
plt.text(0.05, 0.7, f'Lower Bound: {lower_bound:.2f}', transform=plt.gca().transAxes)
plt.text(0.05, 0.65, f'Upper Bound: {upper_bound:.2f}', transform=plt.gca().transAxes)

# Show the plot
plt.show()

# %%
print("median",median)
print("q1",q1)
print("q3",q3)
print("iqr",iqr)
print("lower bound",lower_bound)
print("upper bound", upper_bound)
# Out:
# median 0.6
# q1 0.4
# q3 0.8
# iqr 0.4
# lower bound -0.20000000000000007
# upper bound 1.4000000000000001

# %%
#Printing Outliers
outlier_pt=detect_outliers(data["Concentration"])
len(outlier_pt)
# Out:
# 66

# %%
quantile1, quantile3= np.percentile(data['Concentration'],[25,75])
print(quantile1,quantile3)
# Out:
# 0.4 0.8

# %%
## Find the IQR
iqr=quantile3-quantile1
print(iqr)
# Out:
# 0.4

# %%
## Find the lower bound value and the higher bound value
lower_bound_val = quantile1 -(1.5 * iqr) 
upper_bound_val = quantile3 +(1.5 * iqr) 
print(lower_bound_val,upper_bound_val)
# Out:
# -0.20000000000000007 1.4000000000000001

# %%
data=data.loc[(data['Concentration']>=lower_bound_val)&(data['Concentration']<=upper_bound_val)]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2904 entries, 5 to 3083
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          2904 non-null   int64
#  1   AirPollutant   2904 non-null   object
#  2   Concentration  2904 non-null   float64
#  3   DatetimeEnd    2904 non-null   datetime64[ns, UTC]
#  4   seg_hour       2904 non-null   int64
#  5   day            2904 non-null   int64
#  6   month          2904 non-null   int64
#  7   weekday        2904 non-null   int64
#  8   year           2904 non-null   int64
#  9   weekend        2904 non-null   int64
#  10  day/night      2904 non-null   int64
# dtypes: datetime64[ns, UTC](1), float64(1), int64(8), object(1)
# memory usage: 272.2+ KB

# %%
#Concentration per hour boxplot after removing outliesrs
fig, ax= plt.subplots(figsize= (10,8))
sns.boxplot(data=data,x='seg_hour',y='Concentration')
ax.set_title("Concentration per hour")
plt.show()

# %%
# Calculate the relevant statistics without outliers
median = data['Concentration'].median()
q1 = data['Concentration'].quantile(0.25)
q3 = data['Concentration'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)

# %%
print("median",median)
print("q1",q1)
print("q3",q3)
print("iqr",iqr)
print("lower bound",lower_bound)
print("upper bound", upper_bound)
# Out:
# median 0.5
# q1 0.4
# q3 0.7
# iqr 0.29999999999999993
# lower bound -0.04999999999999988
# upper bound 1.15

# %%
#Creating concentration each month boxplot after removing outliers
fig=plt.figure(figsize=(18,10))
sns.boxplot(data=data,x='month',y='Concentration',color='grey')
plt.title('Concentration per Month',fontsize=20)
plt.xlabel('Month',fontsize=19)
plt.xticks(np.arange(5),labels=['January','February','March','April','May'],fontsize=18)
plt.yticks(fontsize=16)
plt.ylabel('Concentration',fontsize=19)
plt.tight_layout()
plt.show()

# %%
#Creating concentration during each day lineplot after removing outliesrs
fig=plt.figure(figsize=(13,7))
sns.lineplot(data=data,x='day',y='Concentration',ci=None)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.title('Concentration per day',fontsize=19)
plt.xlabel('day',fontsize=18)
plt.ylabel('Concentration',fontsize=18)
plt.tight_layout()
plt.show()

# %%
data.head()
data.reset_index(inplace=True)

# %%
#previous Hours, windows 2-3 (mean, min, max)
def prev_2hours():
   data['prev_2hours']=[data['Concentration'][i] if i==0 else data['Concentration'][i-1] if i==1 else data['Concentration'][i-2]
                                for i in range(len(data))]
prev_2hours()

def prev_two_hours_mean(): #mean of previous two hours (window = 2)
      data['prev_two_hours_mean']=data['index'].apply(lambda x: data['Concentration'].loc[x-2:x-1].mean()).round()
    
prev_two_hours_mean()
    
def prev_two_hours_min(): #minimum of  previous two on  hours (window = 2)
    data['prev_two_hours_min']=data['index'].apply(lambda x: data['Concentration'].loc[x-2:x-1].min())
prev_two_hours_min()
    
def prev_two_hours_max(): #maximum of previous two  hours (window = 2)
     data['prev_two_hours_max']=data['index'].apply(lambda x: data['Concentration'].loc[x-2:x-1].max())
        
prev_two_hours_max()
    
def prev_three_hours_mean(): #mean of previous three  hours (window = 3)
     data['prev_three_hours_mean']=data['index'].apply(lambda x: data['Concentration'].loc[x-3:x-1].mean()).round()
        
prev_three_hours_mean()
    
def prev_three_hours_min(): #minimum of previous three  hours (window = 3)
     data['prev_three_hours_min']=data['index'].apply(lambda x: data['Concentration'].loc[x-3:x-1].min())
        
prev_three_hours_min()
    
def prev_three_hours_max(): #maximum of previous three hours (window = 3)
     data['prev_three_hours_max']=data['index'].apply(lambda x: data['Concentration'].loc[x-3:x-1].max())
        
prev_three_hours_max()
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data[['prev_2hours','Concentration']].head(10) #checking variable prev_2hours
# Out:
#    prev_2hours  Concentration
# 0          1.3            1.3
# 1          1.3            1.1
# 2          1.3            0.9
# 3          1.1            0.6
# 4          0.9            0.7
# 5          0.6            0.7
# 6          0.7            0.9
# 7          0.7            0.9
# 8          0.9            0.8
# 9          0.9            0.7

# %%
data[['prev_two_hours_max','prev_two_hours_min','prev_two_hours_mean','prev_2hours','Concentration']].head(25) #checking
# Out:
#     prev_two_hours_max  prev_two_hours_min  prev_two_hours_mean  prev_2hours  \
# 0                  0.7                 0.6                  1.0          1.3
# 1                  0.7                 0.7                  1.0          1.3
# 2                  0.9                 0.7                  1.0          1.3
# 3                  0.9                 0.9                  1.0          1.1
# 4                  0.9                 0.8                  1.0          0.9
# 5                  0.8                 0.7                  1.0          0.6
# 6                  1.1                 0.7                  1.0          0.7
# 7                  1.2                 1.1                  1.0          0.7
# 8                  1.2                 0.9                  1.0          0.9
# 9                  1.1                 0.9                  1.0          0.9
# 10                 1.1                 1.1                  1.0          0.8
# 11                 1.2                 1.0                  1.0          0.7
# 12                 1.2                 1.1                  1.0          1.1
# 13                 1.4                 1.1                  1.0          1.2
# 14                 1.4                 1.1                  1.0          0.9
# 15                 1.3                 1.1                  1.0          1.1
# 16                 1.3                 1.0                  1.0          1.1
# 17                 1.1                 1.0                  1.0          0.7
# 18                 1.4                 1.1                  1.0          0.6
# 19                 1.4                 1.3                  1.0          0.8
# 20                 1.3                 1.3                  1.0          0.9
# 21                 1.3                 1.2                  1.0          0.9
# 22                 1.2                 1.0                  1.0          1.3
# 23                 1.0                 1.0                  1.0          1.1
# 24                 1.1                 0.8                  1.0          1.0
#
#     Concentration
# 0             1.3
# 1             1.1
# 2             0.9
# 3             0.6
# 4             0.7
# 5             0.7
# 6             0.9
# 7             0.9
# 8             0.8
# 9             0.7
# 10            1.1
# 11            1.2
# 12            0.9
# 13            1.1
# 14            1.1
# 15            0.7
# 16            0.6
# 17            0.8
# 18            0.9
# 19            0.9
# 20            1.3
# 21            1.1
# 22            1.0
# 23            1.4
# 24            1.1

# %%
#Train Test split
data=data.set_index("DatetimeEnd")
train=data.loc[data.index<"2023-04-15"]
test=data.loc[data.index>="2023-04-15"]

# %%
#hape of data train data and test data
print(data.shape)
print(train.shape)
print(test.shape)
# Out:
# (2904, 18)
# (2306, 18)
# (598, 18)

# %%
#Train test split Visualization
fig,ax=plt.subplots(figsize=(15,5))
sns.lineplot(data=train,x='DatetimeEnd',y='Concentration')
sns.lineplot(data=test,x='DatetimeEnd',y='Concentration')
ax.legend(['train set','test set'])
plt.show()

# %%
data.columns
data['Concentration']=data['Concentration'].round()
data['Concentration'].head()
# Out:
# DatetimeEnd
# 2023-01-01 05:00:00+00:00    1.0
# 2023-01-01 06:00:00+00:00    1.0
# 2023-01-01 07:00:00+00:00    1.0
# 2023-01-01 08:00:00+00:00    1.0
# 2023-01-01 09:00:00+00:00    1.0
# Name: Concentration, dtype: float64

# %%
features=['seg_hour', 'day', 'month', 'weekday',
       'year','weekend', 'day/night',"prev_2hours",
       'prev_two_hours_mean', 'prev_two_hours_min', 'prev_two_hours_max',
       'prev_three_hours_mean', 'prev_three_hours_min',
       'prev_three_hours_max']

target="Concentration"

X_train=train[features]
y_train=train[target]
X_test=test[features]
y_test=test[target]

# %%
print(y_train)
# Out:
# DatetimeEnd
# 2023-01-01 05:00:00+00:00    1.3
# 2023-01-01 06:00:00+00:00    1.1
# 2023-01-01 07:00:00+00:00    0.9
# 2023-01-01 08:00:00+00:00    0.6
# 2023-01-01 09:00:00+00:00    0.7
#                             ...
# 2023-04-14 19:00:00+00:00    0.7
# 2023-04-14 20:00:00+00:00    0.6
# 2023-04-14 21:00:00+00:00    0.8
# 2023-04-14 22:00:00+00:00    0.8
# 2023-04-14 23:00:00+00:00    0.4
# Name: Concentration, Length: 2306, dtype: float64

# %%
#Baseline model creation (Evaluation metrics: RMSE, MAE)
Baseline_pred=[data['Concentration'][i] if i==0 else data['Concentration'][i-1] if i==1 else data['Concentration'][i-2]
                                for i in range(len(data))]
data_base=data['Concentration']
rmse_base=np.sqrt(mean_squared_error(data_base,Baseline_pred))
mae_base=mean_absolute_error(data_base,Baseline_pred)
mape_base=mean_absolute_percentage_error(data_base,Baseline_pred)
print("RMSE_base:",rmse_base, "MAE_base:",mae_base,"MAPE_base",mape_base)
# Out:
# RMSE_base: 0.4654006834365961 MAE_base: 0.2165977961432507 MAPE_base 488510290158989.75

# %%
param_grid = {
    'n_estimators': [100, 500, 1000],
    'learning_rate': [0.001, 0.01, 0.1]
}
# Create the XGBoost regressor
model = xgb.XGBRegressor()

# Create the grid search object
grid_search = GridSearchCV(model, param_grid, cv=3, verbose=2)

# %%
# Fit the grid search to the training data
grid_search.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)], verbose=100)

# Print the best parameters and best score
print("Best parameters: ", grid_search.best_params_)
print("Best score: ", grid_search.best_score_)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [0]	validation_0-rmse:0.29080	validation_1-rmse:0.17085
# [99]	validation_0-rmse:0.27466	validation_1-rmse:0.16481
# [CV] END ..............learning_rate=0.001, n_estimators=100; total time=   0.3s
# [0]	validation_0-rmse:0.29080	validation_1-rmse:0.17085
# [99]	validation_0-rmse:0.27419	validation_1-rmse:0.16477
# [CV] END ..............learning_rate=0.001, n_estimators=100; total time=   0.1s
# [0]	validation_0-rmse:0.29078	validation_1-rmse:0.17083
# [99]	validation_0-rmse:0.27330	validation_1-rmse:0.16243
# [CV] END ..............learning_rate=0.001, n_estimators=100; total time=   0.2s
# [0]	validation_0-rmse:0.29080	validation_1-rmse:0.17085
# [100]	validation_0-rmse:0.27450	validation_1-rmse:0.16476
# [200]	validation_0-rmse:0.26056	validation_1-rmse:0.15963
# [300]	validation_0-rmse:0.24814	validation_1-rmse:0.15511
# [400]	validation_0-rmse:0.23712	validation_1-rmse:0.15121
# [499]	validation_0-rmse:0.22765	validation_1-rmse:0.14813
# [CV] END ..............learning_rate=0.001, n_estimators=500; total time=   0.7s
# [0]	validation_0-rmse:0.29080	validation_1-rmse:0.17085
# [100]	validation_0-rmse:0.27403	validation_1-rmse:0.16471
# [200]	validation_0-rmse:0.25945	validation_1-rmse:0.15941
# [300]	validation_0-rmse:0.24685	validation_1-rmse:0.15518
# [400]	validation_0-rmse:0.23594	validation_1-rmse:0.15211
# [499]	validation_0-rmse:0.22655	validation_1-rmse:0.14963
# [CV] END ..............learning_rate=0.001, n_estimators=500; total time=   0.6s
# [0]	validation_0-rmse:0.29078	validation_1-rmse:0.17083
# [100]	validation_0-rmse:0.27313	validation_1-rmse:0.16236
# [200]	validation_0-rmse:0.25787	validation_1-rmse:0.15581
# [300]	validation_0-rmse:0.24442	validation_1-rmse:0.15092
# [400]	validation_0-rmse:0.23293	validation_1-rmse:0.14712
# [499]	validation_0-rmse:0.22306	validation_1-rmse:0.14412
# [CV] END ..............learning_rate=0.001, n_estimators=500; total time=   0.8s
# [0]	validation_0-rmse:0.29080	validation_1-rmse:0.17085
# [100]	validation_0-rmse:0.27450	validation_1-rmse:0.16476
# [200]	validation_0-rmse:0.26056	validation_1-rmse:0.15963
# [300]	validation_0-rmse:0.24814	validation_1-rmse:0.15511
# [400]	validation_0-rmse:0.23712	validation_1-rmse:0.15121
# [500]	validation_0-rmse:0.22756	validation_1-rmse:0.14809
# [600]	validation_0-rmse:0.21915	validation_1-rmse:0.14589
# [700]	validation_0-rmse:0.21183	validation_1-rmse:0.14456
# [800]	validation_0-rmse:0.20546	validation_1-rmse:0.14339
# [900]	validation_0-rmse:0.19989	validation_1-rmse:0.14234
# [999]	validation_0-rmse:0.19509	validation_1-rmse:0.14155
# [CV] END .............learning_rate=0.001, n_estimators=1000; total time=   2.5s
# [0]	validation_0-rmse:0.29080	validation_1-rmse:0.17085
# [100]	validation_0-rmse:0.27403	validation_1-rmse:0.16471
# [200]	validation_0-rmse:0.25945	validation_1-rmse:0.15941
# [300]	validation_0-rmse:0.24685	validation_1-rmse:0.15518
# [400]	validation_0-rmse:0.23594	validation_1-rmse:0.15211
# [500]	validation_0-rmse:0.22646	validation_1-rmse:0.14960
# [600]	validation_0-rmse:0.21824	validation_1-rmse:0.14727
# [700]	validation_0-rmse:0.21103	validation_1-rmse:0.14550
# [800]	validation_0-rmse:0.20478	validation_1-rmse:0.14409
# [900]	validation_0-rmse:0.19927	validation_1-rmse:0.14296
# [999]	validation_0-rmse:0.19442	validation_1-rmse:0.14201
# [CV] END .............learning_rate=0.001, n_estimators=1000; total time=   1.4s
# [0]	validation_0-rmse:0.29078	validation_1-rmse:0.17083
# [100]	validation_0-rmse:0.27313	validation_1-rmse:0.16236
# [200]	validation_0-rmse:0.25787	validation_1-rmse:0.15581
# [300]	validation_0-rmse:0.24442	validation_1-rmse:0.15092
# [400]	validation_0-rmse:0.23293	validation_1-rmse:0.14712
# [500]	validation_0-rmse:0.22297	validation_1-rmse:0.14410
# [600]	validation_0-rmse:0.21387	validation_1-rmse:0.14174
# [700]	validation_0-rmse:0.20578	validation_1-rmse:0.14003
# [800]	validation_0-rmse:0.19872	validation_1-rmse:0.13880
# [900]	validation_0-rmse:0.19257	validation_1-rmse:0.13793
# [999]	validation_0-rmse:0.18731	validation_1-rmse:0.13726
# [CV] END .............learning_rate=0.001, n_estimators=1000; total time=   1.4s
# [0]	validation_0-rmse:0.28919	validation_1-rmse:0.17026
# [99]	validation_0-rmse:0.19490	validation_1-rmse:0.14141
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=   0.1s
# [0]	validation_0-rmse:0.28919	validation_1-rmse:0.17026
# [99]	validation_0-rmse:0.19422	validation_1-rmse:0.14198
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=   0.2s
# [0]	validation_0-rmse:0.28908	validation_1-rmse:0.16998
# [99]	validation_0-rmse:0.18710	validation_1-rmse:0.13726
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=   0.2s
# [0]	validation_0-rmse:0.28919	validation_1-rmse:0.17026
# [100]	validation_0-rmse:0.19440	validation_1-rmse:0.14125
# [200]	validation_0-rmse:0.17051	validation_1-rmse:0.14364
# [300]	validation_0-rmse:0.16156	validation_1-rmse:0.15090
# [400]	validation_0-rmse:0.15667	validation_1-rmse:0.15343
# [499]	validation_0-rmse:0.15405	validation_1-rmse:0.15442
# [CV] END ...............learning_rate=0.01, n_estimators=500; total time=   0.8s
# [0]	validation_0-rmse:0.28919	validation_1-rmse:0.17026
# [100]	validation_0-rmse:0.19376	validation_1-rmse:0.14195
# [200]	validation_0-rmse:0.16626	validation_1-rmse:0.13925
# [300]	validation_0-rmse:0.15595	validation_1-rmse:0.14114
# [400]	validation_0-rmse:0.14954	validation_1-rmse:0.14219
# [499]	validation_0-rmse:0.14627	validation_1-rmse:0.14750
# [CV] END ...............learning_rate=0.01, n_estimators=500; total time=   1.3s
# [0]	validation_0-rmse:0.28908	validation_1-rmse:0.16998
# [100]	validation_0-rmse:0.18664	validation_1-rmse:0.13727
# [200]	validation_0-rmse:0.15815	validation_1-rmse:0.13913
# [300]	validation_0-rmse:0.14701	validation_1-rmse:0.14323
# [400]	validation_0-rmse:0.14129	validation_1-rmse:0.14981
# [499]	validation_0-rmse:0.13732	validation_1-rmse:0.15583
# [CV] END ...............learning_rate=0.01, n_estimators=500; total time=   1.0s
# [0]	validation_0-rmse:0.28919	validation_1-rmse:0.17026
# [100]	validation_0-rmse:0.19440	validation_1-rmse:0.14125
# [200]	validation_0-rmse:0.17051	validation_1-rmse:0.14364
# [300]	validation_0-rmse:0.16156	validation_1-rmse:0.15090
# [400]	validation_0-rmse:0.15667	validation_1-rmse:0.15343
# [500]	validation_0-rmse:0.15404	validation_1-rmse:0.15443
# [600]	validation_0-rmse:0.15248	validation_1-rmse:0.15591
# [700]	validation_0-rmse:0.15092	validation_1-rmse:0.15674
# [800]	validation_0-rmse:0.14990	validation_1-rmse:0.15768
# [900]	validation_0-rmse:0.14896	validation_1-rmse:0.16084
# [999]	validation_0-rmse:0.14872	validation_1-rmse:0.16215
# [CV] END ..............learning_rate=0.01, n_estimators=1000; total time=   2.1s
# [0]	validation_0-rmse:0.28919	validation_1-rmse:0.17026
# [100]	validation_0-rmse:0.19376	validation_1-rmse:0.14195
# [200]	validation_0-rmse:0.16626	validation_1-rmse:0.13925
# [300]	validation_0-rmse:0.15595	validation_1-rmse:0.14114
# [400]	validation_0-rmse:0.14954	validation_1-rmse:0.14219
# [500]	validation_0-rmse:0.14625	validation_1-rmse:0.14760
# [600]	validation_0-rmse:0.14405	validation_1-rmse:0.15089
# [700]	validation_0-rmse:0.14229	validation_1-rmse:0.15350
# [800]	validation_0-rmse:0.14049	validation_1-rmse:0.15518
# [900]	validation_0-rmse:0.13917	validation_1-rmse:0.15680
# [999]	validation_0-rmse:0.13796	validation_1-rmse:0.15880
# [CV] END ..............learning_rate=0.01, n_estimators=1000; total time=   1.8s
# [0]	validation_0-rmse:0.28908	validation_1-rmse:0.16998
# [100]	validation_0-rmse:0.18664	validation_1-rmse:0.13727
# [200]	validation_0-rmse:0.15815	validation_1-rmse:0.13913
# [300]	validation_0-rmse:0.14701	validation_1-rmse:0.14323
# [400]	validation_0-rmse:0.14129	validation_1-rmse:0.14981
# [500]	validation_0-rmse:0.13729	validation_1-rmse:0.15584
# [600]	validation_0-rmse:0.13435	validation_1-rmse:0.15833
# [700]	validation_0-rmse:0.13172	validation_1-rmse:0.16206
# [800]	validation_0-rmse:0.13018	validation_1-rmse:0.16296
# [900]	validation_0-rmse:0.12852	validation_1-rmse:0.16408
# [999]	validation_0-rmse:0.12716	validation_1-rmse:0.16671
# [CV] END ..............learning_rate=0.01, n_estimators=1000; total time=   1.9s
# [0]	validation_0-rmse:0.27346	validation_1-rmse:0.16480
# [99]	validation_0-rmse:0.14806	validation_1-rmse:0.16233
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=   0.2s
# [0]	validation_0-rmse:0.27348	validation_1-rmse:0.16458
# [99]	validation_0-rmse:0.13605	validation_1-rmse:0.15460
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=   0.2s
# [0]	validation_0-rmse:0.27243	validation_1-rmse:0.16206
# [99]	validation_0-rmse:0.12937	validation_1-rmse:0.16513
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=   0.2s
# [0]	validation_0-rmse:0.27346	validation_1-rmse:0.16480
# [100]	validation_0-rmse:0.14788	validation_1-rmse:0.16258
# [200]	validation_0-rmse:0.14642	validation_1-rmse:0.17788
# [300]	validation_0-rmse:0.14734	validation_1-rmse:0.18673
# [400]	validation_0-rmse:0.14794	validation_1-rmse:0.18959
# [499]	validation_0-rmse:0.14854	validation_1-rmse:0.19158
# [CV] END ................learning_rate=0.1, n_estimators=500; total time=   1.2s
# [0]	validation_0-rmse:0.27348	validation_1-rmse:0.16458
# [100]	validation_0-rmse:0.13599	validation_1-rmse:0.15465
# [200]	validation_0-rmse:0.13084	validation_1-rmse:0.16654
# [300]	validation_0-rmse:0.13023	validation_1-rmse:0.17239
# [400]	validation_0-rmse:0.13018	validation_1-rmse:0.17544
# [499]	validation_0-rmse:0.13045	validation_1-rmse:0.17678
# [CV] END ................learning_rate=0.1, n_estimators=500; total time=   1.0s
# [0]	validation_0-rmse:0.27243	validation_1-rmse:0.16206
# [100]	validation_0-rmse:0.12917	validation_1-rmse:0.16525
# [200]	validation_0-rmse:0.12545	validation_1-rmse:0.17592
# [300]	validation_0-rmse:0.12565	validation_1-rmse:0.18065
# [400]	validation_0-rmse:0.12606	validation_1-rmse:0.18458
# [499]	validation_0-rmse:0.12629	validation_1-rmse:0.18494
# [CV] END ................learning_rate=0.1, n_estimators=500; total time=   1.0s
# [0]	validation_0-rmse:0.27346	validation_1-rmse:0.16480
# [100]	validation_0-rmse:0.14788	validation_1-rmse:0.16258
# [200]	validation_0-rmse:0.14642	validation_1-rmse:0.17788
# [300]	validation_0-rmse:0.14734	validation_1-rmse:0.18673
# [400]	validation_0-rmse:0.14794	validation_1-rmse:0.18959
# [500]	validation_0-rmse:0.14854	validation_1-rmse:0.19161
# [600]	validation_0-rmse:0.14894	validation_1-rmse:0.19244
# [700]	validation_0-rmse:0.15023	validation_1-rmse:0.19392
# [800]	validation_0-rmse:0.15029	validation_1-rmse:0.19446
# [900]	validation_0-rmse:0.15058	validation_1-rmse:0.19522
# [999]	validation_0-rmse:0.15058	validation_1-rmse:0.19527
# [CV] END ...............learning_rate=0.1, n_estimators=1000; total time=   1.9s
# [0]	validation_0-rmse:0.27348	validation_1-rmse:0.16458
# [100]	validation_0-rmse:0.13599	validation_1-rmse:0.15465
# [200]	validation_0-rmse:0.13084	validation_1-rmse:0.16654
# [300]	validation_0-rmse:0.13023	validation_1-rmse:0.17239
# [400]	validation_0-rmse:0.13018	validation_1-rmse:0.17544
# [500]	validation_0-rmse:0.13046	validation_1-rmse:0.17679
# [600]	validation_0-rmse:0.13070	validation_1-rmse:0.17881
# [700]	validation_0-rmse:0.13078	validation_1-rmse:0.17905
# [800]	validation_0-rmse:0.13084	validation_1-rmse:0.17896
# [900]	validation_0-rmse:0.13084	validation_1-rmse:0.17896
# [999]	validation_0-rmse:0.13084	validation_1-rmse:0.17896
# [CV] END ...............learning_rate=0.1, n_estimators=1000; total time=   1.5s
# [0]	validation_0-rmse:0.27243	validation_1-rmse:0.16206
# [100]	validation_0-rmse:0.12917	validation_1-rmse:0.16525
# [200]	validation_0-rmse:0.12545	validation_1-rmse:0.17592
# [300]	validation_0-rmse:0.12565	validation_1-rmse:0.18065
# [400]	validation_0-rmse:0.12606	validation_1-rmse:0.18458
# [500]	validation_0-rmse:0.12630	validation_1-rmse:0.18496
# [600]	validation_0-rmse:0.12692	validation_1-rmse:0.18619
# [700]	validation_0-rmse:0.12709	validation_1-rmse:0.18673
# [800]	validation_0-rmse:0.12713	validation_1-rmse:0.18687
# [900]	validation_0-rmse:0.12713	validation_1-rmse:0.18687
# [999]	validation_0-rmse:0.12713	validation_1-rmse:0.18687
# [CV] END ...............learning_rate=0.1, n_estimators=1000; total time=   1.5s
# [0]	validation_0-rmse:0.28906	validation_1-rmse:0.17012
# [100]	validation_0-rmse:0.18284	validation_1-rmse:0.13770
# [200]	validation_0-rmse:0.14994	validation_1-rmse:0.13899
# [300]	validation_0-rmse:0.13389	validation_1-rmse:0.14255
# [400]	validation_0-rmse:0.12414	validation_1-rmse:0.14470
# [499]	validation_0-rmse:0.11646	validation_1-rmse:0.14525
# Best parameters:  {'learning_rate': 0.01, 'n_estimators': 500}
# Best score:  0.3643890246151615

# %%
#Creating the model
model=xgb.XGBRegressor(n_estimators=500,learning_rate=0.01)
model.fit(X_train,y_train,eval_set=[(X_train,y_train),(X_test,y_test)],verbose=100)
# Out:
# [0]	validation_0-rmse:0.28906	validation_1-rmse:0.17012
# [100]	validation_0-rmse:0.18284	validation_1-rmse:0.13770
# [200]	validation_0-rmse:0.14994	validation_1-rmse:0.13899
# [300]	validation_0-rmse:0.13389	validation_1-rmse:0.14255
# [400]	validation_0-rmse:0.12414	validation_1-rmse:0.14470
# [499]	validation_0-rmse:0.11646	validation_1-rmse:0.14525
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=500, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
x=data[['seg_hour', 'day', 'month', 'weekday',
       'year','weekend', 'day/night','prev_2hours',
       'prev_two_hours_mean', 'prev_two_hours_min', 'prev_two_hours_max',
       'prev_three_hours_mean', 'prev_three_hours_min',
       'prev_three_hours_max']]

# %%
fi=pd.DataFrame(data=model.feature_importances_,index=x.columns,columns=['importance'])
fi.sort_values('importance').plot(kind='barh',title='Feature')
plt.show()

# %%
y_pred_train=model.predict(X_train).round()
y_pred_test=model.predict(X_test).round()

# %%
mae_train=mean_absolute_error(y_train,y_pred_train)
mae_train
# Out:
# 0.32818733738074585

# %%
mae_test=mean_absolute_error(y_test,y_pred_test)
mae_test
# Out:
# 0.4175585284280936

# %%
rmse_train=np.sqrt(mean_squared_error(y_train,y_pred_train))
rmse_train
# Out:
# 0.359326246268748

# %%
rmse_test=np.sqrt(mean_squared_error(y_test,y_pred_test))
rmse_test
# Out:
# 0.44208006357298635

# %%
data['Concentration'].describe()
# Out:
# count    2904.000000
# mean        0.487603
# std         0.499932
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: Concentration, dtype: float64

# %%
best=model

explainer = shap.TreeExplainer(best)

# %%
# Get SHAP values for a set of data points
shap_values = explainer.shap_values(x)

# Interpret the first data point using the SHAP values
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values[0], x.iloc[0, :])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='iR9V9H7IC48Y02ISE5DKY'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.6207969784736633, "outValue": 1.0433895587921143, "link": "identity", "featureNames": ["seg_hour", "day", "month", "weekday", "year", "weekend", "day/night", "prev_2hours", "prev_two_hours_mean", "prev_two_hours_min", "prev_two_hours_max", "prev_three_hours_mean", "prev_three_hours_min", "prev_three_hours_max"], "features": {"0": {"effect": 0.00632822047919035, "value": 5.0}, "1": {"effect": 0.07584262639284134, "value": 1.0}, "2": {"effect": 0.038483876734972, "value": 1.0}, "3": {"effect": -0.018093468621373177, "value": 6.0}, "6": {"effect": -0.0009119973401539028, "value": 0.0}, "7": {"effect": 0.30407989025115967, "value": 1.3}, "8": {"effect": 0.0006240502116270363, "value": 1.0}, "9": {"effect": -0.005590690299868584, "value": 0.6}, "10": {"effect": 0.009744629263877869, "value": 0.7}, "11": {"effect": 0.0011566352332010865, "value": 1.0}, "12": {"effect": 0.0030868046451359987, "value": 0.6}, "13": {"effect": 0.00784197449684143, "value": 0.9}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iR9V9H7IC48Y02ISE5DKY')
#   );
# </script>

# %%
# Fits the explainer
explainer = shap.Explainer(model.predict, X_test)
# Calculates the SHAP values - It takes some time
shap_values = explainer(X_test)
# Out:
# Permutation explainer: 599it [02:10,  4.19it/s]

# %%
#Shap values Plot
sns.set_style("white")
shap.summary_plot(shap_values)

# %%
saved_model_path = '/Users/mariatsiompra/Documents/master/diplwmatiki/Forecasting/saved_model/co_model.sav'
os.makedirs(os.path.dirname(saved_model_path), exist_ok=True)
pickle.dump(model, open(saved_model_path, 'wb'))

# %%
# Load saved model 

# loaded_model = pickle.load(open(saved_model_path, 'rb'))
